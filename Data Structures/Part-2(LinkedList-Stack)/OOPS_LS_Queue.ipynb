# %%
class StarCookie:   #here class name is StarCookie
  pass # just to skip the statement
cookie1 = StarCookie()
cookie1.weight = 30
print(cookie1.weight)
# Out:
# 30

# %%
class StarCookie:
  def __init__(self,color):
    self.colour = color
cookie2 = StarCookie("red")
cookie2.weight = 35 #manual way of adding attribute instead of initializer function
print(cookie2.colour)
print(cookie2.weight)
# Out:
# red
# 35

# %%
class StarCookie:
  size = 100 #works as a global attribute but best way is to accessing through funct, since dynamic changing can't happen while creating object
  def __init__(self,color): #sets default to blue for colour and self helps to identify which object is calling it currently
    self.colour = color
cookie2 = StarCookie(color='red')
cookie2.weight = 35 #manual way of adding attribute instead of initializer function
print(cookie2.colour)
print(cookie2.weight)
# Out:
# red
# 35

# %%
class Youtube:
  def __init__(self,username,subscribers=0,subscriptions=0):
    self.subscribers = subscribers
    self.subscriptions = subscriptions
    self.username = username
  def subscribe(self,user2):    #method or functions
    self.subscriptions +=1
    user2.subscribers += 1
user1 = Youtube("Pavan")
user2 = Youtube("sai")
user1.subscribe(user2)
print(f'user1 subscribers are {user1.subscribers}')
print(f'user1 subscriptions are {user1.subscriptions}')
print(f'user2 subscribers are {user2.subscribers}')
print(f'user2 subscribers are {user2.subscriptions}')
# Out:
# user1 subscribers are 0
# user1 subscriptions are 1
# user2 subscribers are 1
# user2 subscribers are 0

# %%
#Linked List
#attributes are value, next pointer
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None
Node1 = Node(value=20)
print(Node1.value)

#attributes are node, head, tail, length
class LinkedList:
  def __init__(self,value):
    new_node = Node(value)
    self.head = new_node # referencing new_node it doesnot create anything new just referencing
    self.tail = new_node # referencing
    self.length = 1

Linkedlist1 = LinkedList(30)
print(Linkedlist1.head)
print(Linkedlist1.head.value)
# Out:
# 20
# <__main__.Node object at 0x79d842571300>
# 30

# %%
#linked list with insertion functionalities
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None
class LinkedList:
  def __init__(self):
    self.head = None
    self.tail = None
    self.length = 0
  def __str__(self):
    temp_node = self.head
    str1=' '
    while(temp_node is not None):
      str1 += str(temp_node.value)
      temp_node = temp_node.next
      str1 += '->'
    return(str1)
  def prepend(self,value):
    if self.head is None:
      new_node = Node(value)
      self.head = new_node
      self.tail = new_node
    else:
      new_node = Node(value)
      new_node.next = self.head
      self.head = new_node
    self.length += 1
  def append(self,value):
    if self.head is None:
      new_node = Node(value)
      self.head = new_node
      self.tail = new_node
    else:
      new_node = Node(value)
      self.tail.next = new_node
      self.tail = new_node
    self.length += 1
  def insert(self,value,index):
    new_node = Node(value)
    temp_node = self.head
    if self.head is None: #edge case if list is empty
      self.head = new_node
      self.tail = new_node
    elif index == 0:   #edge case if want to insert at index 0
      new_node.next = self.head
      self.head = new_node
    elif index < self.length+1: #edge case at end of linked list
      for i in range(index):
        if i == index-1:
          new_node.next = temp_node.next
          temp_node.next = new_node
        else:
          temp_node = temp_node.next
    self.length+=1
  def get(self,index):
      traversal_node = self.head
      for i in range(index+1):
        if i == index:
          value = traversal_node.value
          return value
        else:
          traversal_node = traversal_node.next
  def set(self,index,target):
    traversal_node = self.head
    for i in range(index+1):
      if i == index:
        traversal_node.value = target
        break
      else:
        traversal_node = traversal_node.next
    return(Linkedlist1)
  def pop_first(self):
    # for edge case we need to point head and tail to None using self.length
    temp_node = self.head
    self.head = temp_node.next
    temp_node.next = None
    self.length -= 1
    return(Linkedlist1)
  def pop(self):
    temp_node = self.tail
    front_node = self.head
    k = self.length-2
    for i in range(self.length):
      if i == k:
        front_node.next = None
        self.tail = front_node
      else:
        front_node = front_node.next
    self.length -= 1
    return(Linkedlist1)
  def remove(self,target):
    temp_node = self.head
    for i in range(self.length):
      if temp_node.value is not target:
        prev_node = temp_node
        temp_node = temp_node.next
      else:
        prev_node.next = temp_node.next
        temp_node.next = None
    self.length -= 1
    print(prev_node.value)
    print(temp_node.value)
    return(Linkedlist1)


Linkedlist1 = LinkedList()
Linkedlist1.append(40)
Linkedlist1.append(60)
Linkedlist1.append(80)
# print(Linkedlist1)
# Linkedlist1.prepend(10)
# # print(Linkedlist1)
Linkedlist1.insert(20,3)
print(Linkedlist1.get(2))
print(Linkedlist1.set(2,50))
print(Linkedlist1.remove(50))
# print(Linkedlist1.pop_first())
# print(Linkedlist1.pop())
# print(Linkedlist1.pop())
# Out:
# 80
#  40->60->50->20->
# 60
# 50
#  40->60->

# %%
def replaceElements(arr):
        """
        :type arr: List[int]
        :rtype: List[int]
        """
        for index in range(len(arr)):
            if index < len(arr)-1:
              maximum = max(arr[index+1:])
              arr[index] = maximum
            else:
              arr[index] = -1
        return arr
arr = [17,18,5,4,6,1]
replaceElements(arr)
# Out:
# [18, 6, 6, 6, 1, -1]

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:

    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
        return result

    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def remove(self, index):
        if index < 0 or index >= self.length:
            return None

        # If removing the head node
        if index == 0:
            removed_node = self.head
            self.head = self.head.next
            if self.length == 1:
                self.tail = None
            removed_node.next = None
            self.length -= 1
            return removed_node

        # Removing a node other than the head
        prev_node = self.head
        for i in range(index - 1):
            prev_node = prev_node.next
        removed_node = prev_node.next
        prev_node.next = removed_node.next
        if removed_node == self.tail:
            self.tail = prev_node
        removed_node.next = None
        self.length -= 1
        return removed_node





ls = LinkedList()
ls.append(10)
ls.append(20)
ls.append(30)
print(ls)
print(ls.length)
ls.remove(1)
print(ls)
# Out:
# 10 -> 20 -> 30
# 3
# 10 -> 30

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
    def __str__(self):
        temp_node = self.head
        result = ''
        while temp_node is not None:
            result += str(temp_node.value)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
        return result


    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1

    def find_middle(self):
        # TODO
        current_node = self.head
        k = self.length//2
        for i in range(k+1):
          if i == k:
            return current_node
          else:
            current_node = current_node.next
    def reverse(self):
      temp = None
      current_node = self.head
      while current_node != None:
        next_node = current_node.next
        current_node.next = temp
        temp = current_node
        current_node = next_node
      self.head, self.tail = self.tail, self.head

list1= [1,2,3,4]
list1.reverse()


linkedList = LinkedList()
linkedList.append(20)
linkedList.append(30)

linkedList.append(50)
print(linkedList)
linkedList.reverse()
print(linkedList)
# Out:
# 20 -> 30 -> 50
# 50 -> 30 -> 20

# %%
#circular single linked list
class Node():
  def __init__(self, value):
    self.value = value
    self.next = None
class CircularLinkedList():
  def __init__(self):
    self.head = None
    self.tail = None
    self.length = 0
  def __str__(self):
    temp = self.head
    string = ''
    while(temp is not None):
      if temp == self.tail:
        string += str(temp.value)
        break
      else:
        string += str(temp.value)
        string += '->'
        temp = temp.next
    return(string)

  def append(self,value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
      new_node.next = new_node
    else:
      temp = self.tail
      temp.next = new_node
      new_node.next = self.head
      self.tail = new_node
    self.length += 1
  def prepend(self, value):
    new_node = Node(value)
    temp_tail = self.tail
    if self.head is None:
      self.head = new_node
      self.tail = new_node
      new_node.next = new_node
    else:
      new_node.next = self.head
      self.head = new_node
      temp_tail.next = new_node
    self.length += 1

  def insert(self, index, value):   # we can do using single node pointer only temp upto prev node and updating the new_node
    new_node = Node(value)
    temp = self.head
    prev = temp
    count = 0
    if index >= self.length:
      return None
    else:
      while(temp is not None):
        if index == 0:
          new_node.next = self.head
          self.head = new_node
          self.tail.next = new_node
          self.length += 1
          break
        else:
          if index == count:
            prev.next = new_node
            new_node.next = temp
            self.length += 1
            break
        count += 1
        prev = temp
        temp = temp.next

  def get(self, index):
    if index > self.length:
      return None
    current = self.head
    for _ in range(index):
      current = current.next
    return(current.value)
  def set(self, index, value):
    if index >= self.length:
      return None
    current = self.head
    for i in range(self.length):
      if i == index:
        current.value = value
        break
      else:
        current = current.next
  def pop_first(self):
    temp = self.head
    self.head = temp.next
    temp.next = None
    self.tail.next = self.head
    self.length -= 1
    return(temp)
  def pop(self):
    temp = self.tail
    current = self.head
    for _ in range(self.length-2):
      current = current.next
    current.next = self.head
    self.tail = current
    temp.next = None
    self.length -= 1
  def remove(self,index):
    if index == 0:  #still need to implement edges cases like index< or > length and for empty linked list
      temp = self.head
      self.head = temp.next
      temp.next = None
      self.tail.next = self.head
    else:
      current_node = self.head
      prev_node = current_node
      for _ in range(index):
        prev_node = current_node
        current_node = current_node.next
      prev_node.next = current_node.next
      current_node.next = None
    self.length -= 1
  def delete(self):
    self.head = None
    self.tail = None




cll = CircularLinkedList()
cll.append(20)
cll.append(30)
cll.append(40)
cll.prepend(10)
cll.insert(1,50)
cll.insert(0,60)
print(cll)
print(cll.get(5))
print(cll)
# cll.set(5,10)
# cll.pop_first()
# print(cll)
# cll.pop()
cll.remove(0)
print(cll)
cll.delete()
print(cll)
# Out:
# 60->10->50->20->30->40
# 40
# 60->10->50->20->30->40
# 10->50->20->30->40

# %%
#double linked list
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None
    self.prev = None
  def __str__(self):
    return(str(self.value))
class Linkedlist:
  def __init__(self):
    self.head = None
    self.tail = None
    self.length = 0
  def __str__(self):
    current_node = self.head
    string = ''
    while(current_node != self.tail):
      string += str(current_node.value)
      string += ' <-> '
      current_node = current_node.next
    string += str(current_node.value)
    return(string)
  def append(self,value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next = new_node
      new_node.prev = self.tail
      self.tail = new_node
    self.length += 1
  def prepend(self, value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      new_node.next = self.head
      self.head.prev = new_node
      self.head = new_node
    self.length += 1
  def get(self, index):
    if index < self.length // 2:
      current_node = self.head
      for _ in range(index):
        current_node = current_node.next
      return current_node
    else:
      current_node = self.tail
      for _ in range(self.length-1, index, -1):
        current_node = current_node.prev
      return current_node
  def insert(self,index,value):
    new_node = Node(value)
    prev_node = self.get(index-1)
    new_node.prev = prev_node
    new_node.next = prev_node.next
    prev_node.next.prev = new_node
    prev_node.next = new_node
    self.length += 1
  def pop(self):
    pop_node = self.tail
    self.tail = self.tail.prev
    self.tail.next = None
    pop_node.prev = None
    self.length -= 1
  def remove(self, index):
    prev_node = self.get(index-1)
    current_node = self.get(index)
    prev_node.next = current_node.next
    current_node.prev = None
    prev_node.next.prev = prev_node
    current_node.next = None
    self.length -= 1
    return current_node



ls = Linkedlist()
ls.append(10)
ls.append(20)
ls.append(50)
ls.prepend(30)
ls.prepend(40)
print(ls.get(4))
print(ls)
ls.insert(4,25)
print(ls)
# ls.pop()
ls.remove(3)
print(ls)
# Out:
# 50
# 40 <-> 30 <-> 10 <-> 20 <-> 50
# 40 <-> 30 <-> 10 <-> 20 <-> 25 <-> 50
# 40 <-> 30 <-> 10 <-> 25 <-> 50

# %%
#circular double linked list
class Node:
  def __init__(self, value):
    self.value = value
    self.prev = None
    self.next = None
  def __str__(self):
    return str(self.value)
class CDLL:
  def __init__(self):
    self.head = None
    self.tail = None
    self.length = 0
  def __str__(self):
    current_node = self.head
    string = ' '
    if self.head is None:
      return None
    else:
      while(current_node != self.tail):
        string += str(current_node.value)
        current_node = current_node.next
        string += ' <-> '
        if current_node == self.tail:
          break
      string += str(current_node.value)
      return string
  def append(self, value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
      new_node.next = new_node
      new_node.prev = new_node
    else:
      self.tail.next = new_node
      new_node.prev = self.tail
      new_node.next = self.head
      self.tail = new_node
      self.head.prev = self.tail
    self.length += 1
  def prepend(self, value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
      new_node.next = new_node
      new_node.prev = new_node
    else:
      self.head.prev = new_node
      new_node.next = self.head
      new_node.prev = self.tail
      self.tail.next = new_node
      self.head = new_node
    self.length += 1
  def get(self, index):
    if index < self.length // 2:
      current_node = self.head
      for _ in range(index):
        current_node = current_node.next
      return current_node
    else:
      current_node = self.tail
      for _ in range(self.length-1, index, -1):
        current_node = current_node.prev
      return current_node
  def insert(self, index, value): #edge cases need to be covered
    new_node = Node(value)
    current_node = self.get(index-1)
    current_node.next.prev = new_node
    new_node.next = current_node.next
    current_node.next = new_node
    new_node.prev = current_node
    self.length += 1
  def pop(self): # edge cases not covered
    current_node = self.tail
    current_node.prev.next = self.head
    self.tail = current_node.prev
    self.head.prev = self.tail
    current_node.prev = None
    current_node.next = None
    self.length -= 1
    return current_node
  def pop_first(self):  #edge cases not covered
    current_node = self.head
    self.head = current_node.next
    self.head.prev = self.tail
    current_node.prev = None
    current_node.next = None
    self.tail.next = self.head
    self.length -= 1
    return current_node
  def remove(self, index): #edge cases not covered
    remove_node = self.get(index)
    remove_node.prev.next = remove_node.next
    remove_node.next.prev = remove_node.prev
    remove_node.prev = None
    remove_node.next = None
    self.length -= 1


cdll = CDLL()
cdll.append(10)
cdll.append(20)
cdll.append(30)
cdll.append(40)
cdll.prepend(50)
print(cdll)
cdll.insert(2,60)
print(cdll)
print(cdll.lastelement(3))
# cdll.pop()
# print(cdll)
# cdll.pop_first()
# print(cdll)
# cdll.remove(2)
# print(cdll)
# Out:
#  50 <-> 10 <-> 20 <-> 30 <-> 40
#  50 <-> 10 <-> 60 <-> 20 <-> 30 <-> 40
# 20

# %%
#stack using list
class stack:
  def __init__(self,maxsize):
    self.list = []
    self.maxsize = maxsize
  def __str__(self):
    values = [str(i) for i in reversed(self.list)]
    return '\n'.join(values)
  def push(self,value):
    if len(self.list) >= self.maxsize:
      return 'max size is reached'
    else:
      self.list.append(value)
      return 'element is inserted successfully'
  def is_empty(self):
    if self.list == []:
      return True
    else:
      return False
  def pop(self):
    if self.is_empty():
      return 'there is nothing to pop'
    else:
      return (self.list.pop())
  def peek(self):
    if self.is_empty():
      return 'there is nothing to peek'
    else:
      return (self.list[len(self.list)-1])
  def delete(self):
    self.list = []
    return 'list is empty successfully'

stack1 = stack(2)
stack1.push(20)
stack1.push(30)
print(stack1.push(40))
print(stack1)
stack1.pop()
print(stack1)
print(stack1.peek())
print(stack1.delete())
print(stack1.is_empty())
# Out:
# max size is reached
# 30
# 20
# 20
# 20
# list is empty successfully
# True

# %%
#stack using linked list (SLL) but only with head
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None
class Stack:
  def __init__(self):
    self.head = None
  def __str__(self):
    current_node = self.head
    result = ''
    while(current_node):
      result += str(current_node.value)
      current_node = current_node.next
      if current_node is None:
        break
      else:
        result += '->'
    return result

  def push(self, value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
    else:
      new_node.next = self.head
      self.head = new_node
  def pop(self):
    if self.is_empty():
      return 'empty stack'
    else:
      current_node = self.head
      self.head = self.head.next
      current_node.next = None
  def is_empty(self):
    if self.head is None:
      return True
    else:
      return False
  def peek(self):
    if self.head is None:
      return None
    else:
      return self.head.value
  def delete(self):
    self.head = None
    return 'stack deleted successfully'
stack1 = Stack()
stack1.push(2)
stack1.push(3)
stack1.push(4)
print(stack1)
stack1.pop()
print(stack1)
print(stack1.is_empty())
print(stack1.peek())
# Out:
# 4->3->2
# 3->2
# False
# 3

# %%
#queue using list without size limitation
class Queue:
  def __init__(self):
    self.list1 = []
  def __str__(self):
    result = ''
    for i in self.list1:
      result += str(i)
      result += ' '
    return(result)

  def enqueue(self, value):
    self.list1.append(value)
  def dequeue(self):
    self.list1.pop(0)
  def peek(self):
    return(self.list1[0])
  def delete(self):
    self.list1 = []
  def is_empty(self):
    if self.list1 == []:
      return True
    else:
      return False
queue1 = Queue()
queue1.enqueue(1)
queue1.enqueue(2)
queue1.enqueue(3)
queue1.enqueue(4)
queue1.enqueue(5)
queue1.dequeue()
print(queue1.peek())
print(queue1)
queue1.delete()
print(queue1.is_empty())
# Out:
# 2
# 2 3 4 5
# True

# %%
# queue using size limitation with circular queue here main ageneda is using same size and appending elements whererever elements are None
class CircularQueue:
  def __init__(self, maxsize):
    self.list1 = [None] * maxsize
    self.maxsize = maxsize
    self.start = -1
    self.top = -1
  def __str__(self):
    result = ''
    for i in self.list1:
      result += str(i)
      result += ' '
    return(result)
  def is_empty(self):
    if self.start == -1:
      return True
    else:
      return False
  def is_Full(self):
    if self.top+1 == self.start:
      return True
    elif self.start == 0 and self.top+1 == self.maxsize:
      return True
    else:
      return False
  def enqueue(self, value):
    if self.is_empty() or not self.is_Full():
       if self.start == -1:
        self.start = 0
        self.top = 0
       elif self.top+1 == self.maxsize:
        self.top = 0
       else:
        self.top += 1
       self.list1[self.top] = value
    else:
      return "queue is Full"
  def dequeue(self):
    if not self.is_empty():
      start = self.start
      if self.start == self.top:
        self.start = -1
        self.top = -1
      elif self.start +1 == self.maxsize:
        self.start = 0
      else:
        self.start += 1
      self.list1[start] = None
    else:
      return "List is empty"
  def delete(self):
    self.list1 = [None] * maxsize
    self.start = -1
    self.top = -1
  def peek(self):
    return(self.list1[self.start])


CQ1 = CircularQueue(5)
CQ1.enqueue(1)
CQ1.enqueue(2)
CQ1.enqueue(3)
CQ1.enqueue(4)
CQ1.enqueue(5)
CQ1.dequeue()
CQ1.dequeue()
CQ1.dequeue()
CQ1.enqueue(1)
print(CQ1)
# Out:
# 1 None None 4 5

# %%
#queue using Linked List
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None
class LinkedList:
  def __init__(self):
    self.tail = None
    self.head = None
  def __str__(self):
    current_node = self.head
    result = ''
    while(current_node):
      result += str(current_node.value)
      current_node = current_node.next
      if current_node is None:
        break
      else:
        result += '->'
    return result
  def enqueue(self,value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next = new_node
      self.tail = new_node
  def dequeue(self):
    temp = self.head
    if self.head is None:
      return "Queue is Empty"
    if self.head == self.tail:
      self.head = None
      self.tail = None
    else:
      self.head = self.head.next
      temp.next = None
    return temp
  def is_empty(self):
    if self.head is None:
      return True
    else:
      return False
  def peek(self):
    if self.is_empty():
      return "Nothing in Queue"
    else:
      return self.head.value
  def delete(self):
    self.head = None
    self.tail = None

LL = LinkedList()
LL.enqueue(1)
LL.enqueue(2)
LL.enqueue(3)
LL.enqueue(4)
LL.enqueue(5)
print(LL)
LL.dequeue()
LL.dequeue()
print(LL)
print(LL.peek())
LL.delete()
print(LL)
print(LL.is_empty())
# Out:
# 1->2->3->4->5
# 3->4->5
# 3
#
# True

# %%
from collections import deque
queue = deque()
queue.append(1)
queue.append(2)
queue.append(3)
print(queue)
queue.popleft()
print(queue)
# Out:
# deque([1, 2])
# deque([2])

# %%
import queue as q2
q1 = q2.Queue()
q1.put(1)
q1.put(2)
print(q1)
# Out:
# <queue.Queue object at 0x7ed998522950>
